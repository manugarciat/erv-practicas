# %% [markdown]
# ## Práctica 1 - Operadores puntuales e histograma

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open("seeds.jpg").convert(mode='L')
r = np.array(img)

# %%
r.shape
# Out:
# (500, 500)

# %% [markdown]
# ### Imágen original:

# %%
plt.figure(figsize = (10,10))
p = plt.imshow(r, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# ### Ejercicio 1
